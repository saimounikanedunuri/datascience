# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sanedunu\anaconda3\lib\site-packages (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sanedunu\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: six>=1.5 in c:\users\sanedunu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.5.1

# %% [markdown]
# # pyplot

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting without line
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#multiple points
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#default x-points
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Markers

# %%
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
plt.plot(ypoints, marker = '*')
plt.show()

# %%
#Format strings fmt
#syntax: marker|line|color
plt.plot(ypoints, 'o:r')
plt.show()

# %%
#marker size
plt.plot(ypoints, marker = 'o', ms = 10)
plt.show()

# %%
#mec- marker edge color
plt.plot(ypoints, marker = 'o', ms = 10, mec = 'r')
plt.show()

# %%
#mfc - marker face color
plt.plot(ypoints, marker = 'o', ms = 10, mfc = 'r')
plt.show()

# %%
#use both mec, mfc
plt.plot(ypoints, marker = 'o', ms = 10, mec = 'r', mfc = 'r')
plt.show()

# %%
#green color
plt.plot(ypoints, marker = 'o', ms = 10, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %%
#hotpink color
plt.plot(ypoints, marker = 'o', ms = 10, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# # Line

# %%
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
#set color as red
plt.plot(ypoints, color = 'r')
plt.show()

# %%
#color- green
plt.plot(ypoints, c = '#4CAF50')
plt.show()

# %%
#color-hotpink
plt.plot(ypoints, c = 'hotpink')
plt.show()

# %%
#linewidth
plt.plot(ypoints, linewidth = '10.5')
plt.show()

# %%
#multiple lines
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # Lables and titles

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#title
plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
#set font properties
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#position title
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Grid

# %%
plt.plot(x, y)

plt.grid()

plt.show()

# %%
#specify grid lines to display
plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
plt.plot(x, y)
plt.grid(axis = 'y')

plt.show()

# %%
#line property
plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# # Subplot

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
#draw 6 plots
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Scatter

# %%
plt.scatter(x, y)
plt.show()

# %%
#compare plots
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
#colors
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
#color each plot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
#color map
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
#include actual colormap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# # Bars

# %%
#creating bars
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
#horizontal bars
plt.barh(x, y)
plt.show()

# %%
#bar color
plt.bar(x, y, color = "red")
plt.show()

# %%
#color names
plt.bar(x, y, color = "hotpink")
plt.show()

# %%
#hexagonal colors
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
#bar width
plt.bar(x, y, width = 0.1)
plt.show()

# %%
#bar height
plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# # Histogram

# %%
x = np.random.normal(170, 10, 150)

print(x)
# Out:
# [176.25921257 167.64812855 158.50437853 183.6977753  162.37552031
#  163.2379507  169.09681904 146.56244553 148.31998091 179.19581837
#  165.94394224 174.17801164 164.99431549 175.17762043 156.79823402
#  160.60981458 184.17469862 175.02205941 183.33875616 171.31903622
#  165.53327032 176.95659266 163.11150871 164.38890954 177.39326301
#  189.19562772 183.64253074 155.77979609 172.00621711 173.30394671
#  178.9026838  185.71022556 166.17712442 189.8565145  166.23781967
#  174.42146892 167.686785   173.25408126 172.63479944 162.41156564
#  163.67534737 163.92436334 165.80622636 162.33662745 169.08726206
#  170.65524664 173.70631629 184.38043236 153.67981706 180.47486278
#  165.33484676 174.33556709 167.80648652 189.35824955 181.93042606
#  178.71246358 147.81499389 189.16561527 164.85763977 174.03747561
#  161.23217617 159.81588167 175.58692533 163.72175223 184.52185568
#  176.92728372 165.01881527 157.68502502 145.03556697 189.30149673
#  185.04031989 165.57533516 173.61736044 169.51848619 172.57918389
#  162.03302922 158.9165255  172.92119193 190.37459382 168.91718866
#  174.17140177 165.96521299 155.50808409 181.60573497 185.25115177
#  166.49947638 163.10071051 163.41372727 175.02681134 170.15677296
#  162.33581524 160.31471474 165.9493735  148.12205989 160.22847496
#  187.65720548 164.71028709 170.1981247  163.882793   167.30062528
#  161.01421125 164.38979321 169.09067057 160.13456629 167.05418579
#  163.13688014 173.53750812 168.60717285 170.78907353 162.72361431
#  174.93746366 174.73954688 170.97642868 181.66270032 158.78095964
#  159.75110524 162.68485173 158.08817641 174.48443461 175.91908227
#  158.44704922 144.14216487 176.36983507 176.70184085 165.79647515
#  164.83750032 162.57778199 167.23487935 169.93195713 187.36703284
#  169.07334792 163.04430375 151.59053479 169.44994602 163.80284219
#  172.68232241 166.29777997 169.0584175  158.27376426 166.93168778
#  173.65999733 153.3788613  182.03829176 156.05040772 158.24047892
#  168.24675447 163.16779522 167.92690693 173.16236344 176.57105363]

# %%
plt.hist(x)
plt.show()

# %% [markdown]
# # Pie chart

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
#labels
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#start angle
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#stand out - explode
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#shadow
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#colors
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#legend
plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#legend with header
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
